# %% [markdown]
# ## Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,20,1000)
#1-d Array with 1000 Evenly Spaced Points between 0 & 20

# %%
y = np.sin(x) + 0.2*x

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.xlabel('input')
plt.ylabel('output')
plt.title('my plot');

# %% [markdown]
# ### Scatterplot

# %%
X = np.random.randn(100,2)
plt.scatter(X[:,0], X[:, 1]);

# %%
X = np.random.randn(200,2)
X[:50] +=3
Y = np.zeros(200)
Y[:50] = 1
plt.scatter(X[:,0],X[:,1],c=Y);

# %% [markdown]
# ### Histogram

# %%
X = np.random.randn(10000)
plt.hist(X);

# %%
plt.hist(X,bins=50);

# %%
X = np.random.random(10000)
plt.hist(X, bins=50);

# %% [markdown]
# ### Plotting Images

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
im = Image.open("C:/Users/Administrator/Downloads/gear-5-look.webp")

# %%
type(im)
# Out:
# PIL.WebPImagePlugin.WebPImageFile

# %%
arr = np.array(im)
arr
# Out:
# array([[[  3,   0,  46],
#         [  3,   0,  46],
#         [  3,   0,  46],
#         ...,
#         [  0,   1,  46],
#         [  0,   1,  46],
#         [  0,   1,  46]],
#
#        [[  3,   0,  46],
#         [  3,   0,  46],
#         [  3,   0,  46],
#         ...,
#         [  0,   1,  46],
#         [  0,   1,  46],
#         [  0,   1,  46]],
#
#        [[  3,   0,  46],
#         [  3,   0,  46],
#         [  3,   0,  46],
#         ...,
#         [  0,   1,  46],
#         [  0,   1,  46],
#         [  0,   1,  46]],
#
#        ...,
#
#        [[ 67,  47, 113],
#         [ 67,  47, 113],
#         [ 67,  47, 113],
#         ...,
#         [ 44,   7,  40],
#         [ 45,   5,  39],
#         [ 45,   5,  41]],
#
#        [[ 64,  46, 114],
#         [ 64,  46, 114],
#         [ 64,  46, 114],
#         ...,
#         [ 44,   4,  40],
#         [ 43,   3,  39],
#         [ 43,   2,  41]],
#
#        [[ 64,  46, 116],
#         [ 64,  46, 116],
#         [ 64,  46, 116],
# ...

# %%
arr.shape
# Out:
# (422, 750, 3)

# %%
plt.imshow(arr);

# %%
plt.imshow(im);

# %%
gray = arr.mean(axis=2)

# %%
gray.shape
# Out:
# (422, 750)

# %%
plt.imshow(gray);

# %%
plt.imshow(gray, cmap ='gray');

# %% [markdown]
# ### Exercise

# %%
X = np.random.randn(200,2)
X[:50] +=3
Y = np.zeros(200)
Y[:50] = 1
plt.scatter(X[:,0],X[:,1],c=Y);

# %%
# Generate XOR dataset
np.random.seed(42)

# Class 0
X0 = np.random.randn(50, 2)
X0 += np.array([-2, -2])

# Class 1
X1 = np.random.randn(50, 2)
X1 += np.array([2, 2])

# Class 2
X2 = np.random.randn(50, 2)
X2 += np.array([-2, 2])

# Class 3
X3 = np.random.randn(50, 2)
X3 += np.array([2, -2])

# Concatenate the data
X = np.vstack([X0, X1, X2, X3])
y = np.array([0] * 50 + [0] * 50 + [1] * 50 + [1] * 50)

# Plot the XOR dataset
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.title("XOR Dataset")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
